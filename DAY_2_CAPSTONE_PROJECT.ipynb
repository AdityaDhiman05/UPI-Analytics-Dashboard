# %% [markdown]
# <a href="https://colab.research.google.com/github/AdityaDhiman05/UPI-Fraud-Detection-Project/blob/main/DAY_2_CAPSTONE_PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Day 2: UPI Growth Visualization 📊
#
# This notebook continues the Capstone Project on UPI transactions.
# ✅ Imported dataset from Kaggle
# ✅ Used Google Colab for coding
# ✅ Created combined visualizations (Volume & Value growth)

# %%
import pandas as pd

import seaborn as sns
sns.set(style="whitegrid")
# %matplotlib inline
# !pip install matplotlib-venn

# %% [markdown]
# now i will load the csv fie and to check wether it have succesfully loaded use head() method to check first five rows

# %%
import pandas as pd
df = pd.read_csv('upi_data_enhanced.csv')
df.head()
# Out:
#     Month  No. of Banks live on UPI  Volume (in Mn)  Value (in Cr.)  \
# 0  Aug-25                       688        20008.31      2485472.91
# 1  Jul-25                       684        19467.95      2508498.09
# 2  Jun-25                       675        18395.01      2403930.69
# 3  May-25                       673        18677.46      2514297.01
# 4  Apr-25                       668        17893.42      2394925.87
#
#    Avg_Txn_Value_INR  MoM_Growth_Volume_%  MoM_Growth_Value_%
# 0        1242.220312             2.775639           -0.917887
# 1        1288.527087             5.832777            4.349851
# 2        1306.838480            -1.512251           -4.389550
# 3        1346.166454             4.381722            4.984335
# 4        1338.439421            -2.229816           -3.322098

# %% [markdown]
# now will check data structures and will look for any missing values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113 entries, 0 to 112
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Month                     113 non-null    object
#  1   No. of Banks live on UPI  113 non-null    int64
#  2   Volume (in Mn)            113 non-null    float64
#  3   Value (in Cr.)            113 non-null    float64
#  4   Avg_Txn_Value_INR         110 non-null    float64
#  5   MoM_Growth_Volume_%       110 non-null    float64
#  6   MoM_Growth_Value_%        110 non-null    float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 6.3+ KB

# %%
df.describe()
# Out:
#        No. of Banks live on UPI  Volume (in Mn)  Value (in Cr.)  \
# count                113.000000      113.000000    1.130000e+02
# mean                 272.539823     5153.367522    7.781111e+05
# std                  208.902533     5964.246855    8.287286e+05
# min                   21.000000        0.000000    0.000000e+00
# 25%                  114.000000      312.020000    5.421226e+04
# 50%                  207.000000     2234.160000    4.161762e+05
# 75%                  414.000000     8863.260000    1.415505e+06
# max                  688.000000    20008.310000    2.514297e+06
#
#        Avg_Txn_Value_INR  MoM_Growth_Volume_%  MoM_Growth_Value_%
# count         110.000000           110.000000          110.000000
# mean         1786.563888                  inf                 inf
# std           703.857367                  NaN                 NaN
# min            42.222222           -19.831735          -26.795036
# ...

# %%
df.isnull().sum()
# Out:
# Month                       0
# No. of Banks live on UPI    0
# Volume (in Mn)              0
# Value (in Cr.)              0
# Avg_Txn_Value_INR           3
# MoM_Growth_Volume_%         3
# MoM_Growth_Value_%          3
# dtype: int64

# %%
df['Month']=pd.to_datetime(df['Month'],format='%b-%y')

# %%
df.sort_values('Month')
# Out:
#          Month  No. of Banks live on UPI  Volume (in Mn)  Value (in Cr.)  \
# 112 2016-04-01                        21            0.00            0.00
# 111 2016-05-01                        21            0.00            0.00
# 110 2016-06-01                        21            0.00            0.00
# 109 2016-07-01                        21            0.09            0.38
# 108 2016-08-01                        21            0.09            3.09
# ..         ...                       ...             ...             ...
# 4   2025-04-01                       668        17893.42      2394925.87
# 3   2025-05-01                       673        18677.46      2514297.01
# 2   2025-06-01                       675        18395.01      2403930.69
# 1   2025-07-01                       684        19467.95      2508498.09
# 0   2025-08-01                       688        20008.31      2485472.91
#
#      Avg_Txn_Value_INR  MoM_Growth_Volume_%  MoM_Growth_Value_%
# ...

# %% [markdown]
# visualizing upi growth - volume growth

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
plt.plot(df['Month'], df['Volume (in Mn)'], marker='o', color='blue', label='Volume (Mn)')
plt.title('UPI Transaction Volume Growth Over Time')
plt.xlabel('Month')
plt.ylabel('Volume (in Million)')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# upi growth visualization - value growth

# %%
plt.figure(figsize=(12,6))
plt.plot(df['Month'], df['Value (in Cr.)'], marker='o', color='green', label='Value (Cr.)')
plt.title('UPI Transaction Value Growth Over Time')
plt.xlabel('Month')
plt.ylabel('Value (Crores ₹)')
plt.xticks(rotation=45)
plt.grid(True)
plt.legend()
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(12,6))

color = 'tab:blue'
ax1.set_xlabel('Month')
ax1.set_ylabel('Volume (Mn)', color=color)
ax1.plot(df['Month'], df['Volume (in Mn)'], color=color, marker='o')
ax1.tick_params(axis='y', labelcolor=color)
ax1.tick_params(axis='x', rotation=45)

ax2 = ax1.twinx()  # second y-axis
color = 'tab:green'
ax2.set_ylabel('Value (Cr.)', color=color)
ax2.plot(df['Month'], df['Value (in Cr.)'], color=color, marker='s')
ax2.tick_params(axis='y', labelcolor=color)

plt.title('UPI Volume and Value Growth Over Time')
plt.grid(True)
plt.show()

# %%
fig.savefig('upi_volume_value_growth.png', bbox_inches='tight')
